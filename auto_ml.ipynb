# %% [markdown]
# <a href="https://colab.research.google.com/github/f3lipems/big-data-science/blob/main/auto_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Auto ML
# ## Automatização de tarefas de ML

# %%
# Auto ML - Automatizar tarefas de ML
# pyCaret
# !pip install pycaret
import pandas as pd
from pycaret.classification import *

# %%
# 2. Carga de Dados
df = pd.read_csv('https://raw.githubusercontent.com/diogenesjusto/FIAP/master/Gradua%C3%A7%C3%A3o/dados/dados_arvore_titanic.csv')

# %%
# 3. Setup do conjunto de dados no AutoML - pycaret

s = setup(df, target='Survived')
# Out:
# <style type="text/css">
# #T_79993_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_79993" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79993_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_79993_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79993_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79993_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_79993_row0_col1" class="data row0 col1" >5512</td>
#     </tr>
#     <tr>
#       <th id="T_79993_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_79993_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_79993_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_79993_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# 4. Comparação de modelos/algorítimos

best = compare_models()
# Out:
# <style type="text/css">
# #T_3224e th {
#   text-align: left;
# }
# ...

# %%
# 5. Avaliação de modelos

evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
